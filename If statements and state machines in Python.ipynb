# %% [markdown]
# # If Statements  and State Machines in Python

# %% [markdown]
# # 1. If Statements

# %%
a = 2
b = 3

if a < b:
    print("a is less than b")
# Out:
# a is less than b

# %%
a = 3
b = 3

if a < b:
    print("a is less than b")
elif a == b:
    print("a is equal to b")
else:
    print("a is greater than b")
# Out:
# a is equal to b

# %%
a = 2
b = 3

if a < b: print("a is less than b")
# Out:
# a is less than b

# %%
a = 4
b = 3

print("a is less than b") if a < b else print("a is greater than or equal to b")

# %% [markdown]
# # 2. Logic Operators and Conditions

# %%
a = 2
b = 3
c = 4

# And operator - Both conditions has to be true
if a < b and a < c:
    print("Both conditions are true")
# Out:
# Both conditions are true

# %%
a = 2
b = 3
c = 4

# Or operator - Only one condition has to be true
if a < b or a > c:
    print("One condition is true")
# Out:
# One condition is true

# %% [markdown]
# # 3. State Machines

# %% [markdown]
# # ![statemachine.png](attachment:statemachine.png)

# %%
state = 0

doorClosed = 1
doorOpen = 2
doorLocked = 3

handle = 1
key = 0

state = doorClosed

if state == doorClosed:
    if(handle):
        state = doorOpen
    if(key):
        state = doorLocked
elif state == doorOpen:
    if(key):
        pass#do nothing
    if(handle):
        state = doorclosed
elif state == doorLocked:
    if(handle):
        pass#do nothing
    if(key):
        state = doorClosed
