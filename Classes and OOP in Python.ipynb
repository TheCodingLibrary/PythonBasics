# %% [markdown]
# # Classes and OOP in Python - Explanation

# %% [markdown]
# # 1. Classes and OOP Overview

# %% [markdown]
# ![4522286854963200.png](attachment:4522286854963200.png)

# %% [markdown]
# # 2. What is an object and how does it work?

# %% [markdown]
# ![oop.jpg](attachment:oop.jpg)

# %% [markdown]
# # 3. Examples of classes and subclasses

# %% [markdown]
# ![oop2.png](attachment:oop2.png)
